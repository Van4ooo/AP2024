# %%
from AP2024.sorts import PyCombSort, PyIntroSort, PySmoothSort
from AP2024 import Measurement, Diagram, D, SortParam

# %%
# chart with input sorted arrays by sort time
Diagram(
    SortParam.time,
    D([PyIntroSort, PySmoothSort, PyCombSort], 'sort')
)

# %%
# chart with input unsorted arrays by sort time
Diagram(
    SortParam.time,
    D([PyIntroSort, PySmoothSort, PyCombSort], 'rand')
)

# %%
# chart with input reversed arrays by sort time
Diagram(
    SortParam.time,
    D([PyIntroSort, PySmoothSort, PyCombSort], 'rev')
)

# %%
# may draw many diagrams
Diagram(
        SortParam.access,
        D([PyIntroSort, PySmoothSort, PyCombSort], 'sort'),
        D([PyIntroSort, PySmoothSort, PyCombSort], 'rev'),
        D([PyIntroSort, PySmoothSort, PyCombSort], 'rand'),
        one_diagram=False
    )
